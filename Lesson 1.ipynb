# %% [markdown]
# Exercise 1 - Printing Text

# %%
print("Hello, World!")
print("My name is Owolabi Ayotomiwa.")
print("I am learning Python.")
print("Programming is exciting!")
# Out:
# Hello, World!
# My name is Owolabi Ayotomiwa.
# I am learning Python.
# Programming is exciting!

# %% [markdown]
# Exercise 2 - Multiple Print Statements

# %%
print("My favorite food is Jollof Rice.")
print("My favorite movie is The Originals.")
print("My favorite sports is Football.")
print("My favorite color is Black.")
# Out:
# My favorite food is Jollof Rice.
# My favorite movie is The Originals.
# My favorite sports is Football.
# My favorite color is Black.

# %% [markdown]
# Exercise 3 - Python Calculator

# %%
print(15 + 5)
print(30 - 12)
print(9 * 8)
print(72 / 9)
print(18 % 5)
print(10 // 3)
print(5 ** 2)
# Out:
# 20
# 18
# 72
# 8.0
# 3
# 3
# 25

# %% [markdown]
# Exercise 4 - Understanding Comments

# %%
#Display programming language
print("Python")

#Display programming word
print("Programming")

#Display first lesson
print("Lesson One")
# Out:
# Python
# Programming
# Lesson One

# %% [markdown]
# Exercise 5 - Mini Challenge

# %%
#Display name
print("My name is Owolabi Ayotomiwa.")

#Display dream career
print("My dream career is becoming an Artificial Intelligience and Machine Learning Engineer.")

#Display country
print("My country is Nigeria.")

#Display calculation result
print(25 + 75)

#Display calculation result
print(40 // 6)

#Display calculation result
print(8 ** 2)
# Out:
# My name is Owolabi Ayotomiwa.
# My dream career is becoming an Artificial Intelligience and Machine Learning Engineer.
# My country is Nigeria.
# 100
# 6
# 64
