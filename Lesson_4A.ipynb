# %% [markdown]
# # Exercise 1 - Secure Login System

# %%
# Task
user_name = True
password_correct = True
account_locked = False

print("Task: ")

if user_name and password_correct and not account_locked:
    print("Access Granted!")
else:
    print("Acces Denied!")

print(" ")

# Challenge
user_name = False
password_correct = False
account_locked = True

print("Challenge: ")

if user_name and password_correct and not account_locked:
    print("Access Granted!")
else:
    print("Acces Denied!")
# Out:
# Task:
# Access Granted!
#
# Challenge:
# Acces Denied!

# %% [markdown]
# # Exercise 2 - University Scholarship Eligibility

# %%
# Task
score = 85
participated = True
low_income = False

print("Task: ")

if score >= 80 and (participated or low_income):
    print("Congratulations!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")

print(" ")



# Challenge 1
score = 85
participated = False
low_income = False

print("Challenge 1: ")

if score >= 80 and (participated or low_income):
    print("Congratulations!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")

print(" ")

# Reason: The score is high, but neither of the additional conditions is true.



# Challenge 2
score = 40
participated = True
low_income = False

print("Challenge 2: ")

if score >= 80 and (participated or low_income):
    print("Congratulations!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")

print(" ")

# Reason: The score is below 80.




# Challenge 3
score = 85
participated = True
low_income = True

print("Challenge 3: ")

if score >= 80 and (participated or low_income):
    print("Congratulations!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")

print(" ")

# Reason: The score is at least 80 and the student is from a low-income family.




# Challenge 4
score = 85
participated = True
low_income = True

print("Challenge 4: ")

if score >= 80 and (participated or low_income):
    print("Congratulations!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")

# Reason: All conditions are met.
# Out:
# Task:
# Congratulations!
# Scholarship Approved.
#
# Challenge 1:
# Scholarship Not Approved.
#
# Challenge 2:
# Scholarship Not Approved.
#
# Challenge 3:
# Congratulations!
# Scholarship Approved.
#
# Challenge 4:
# Congratulations!
# Scholarship Approved.

# %% [markdown]
# # Exercise 3 - Smart Server Health Monitor

# %%
# Task
cpu_usage = 75
memory_usage = 92
disk_usage = 60

print("Task: ")

if cpu_usage > 90 or memory_usage > 90 or disk_usage > 60:
    print("Critical Alert!")
else:
    print("System Healthy!")

print(" ")

# Challenge 1
cpu_usage = 70
memory_usage = 70
disk_usage = 70

print("Challenge 1: ")

if cpu_usage > 90 or memory_usage > 90 or disk_usage > 60:
    print("Critical Alert!")
else:
    print("System Healthy!")

print(" ")


# Challenge 3
cpu_usage = 90
memory_usage = 92
disk_usage = 60

print("Challenge 2: ")

if cpu_usage > 90 or memory_usage > 90 or disk_usage > 60:
    print("Critical Alert!")
else:
    print("System Healthy!")

print(" ")

# Challenge 3
cpu_usage = 75
memory_usage = 95
disk_usage = 60

print("Challenge 3: ")

if cpu_usage > 90 or memory_usage > 90 or disk_usage > 60:
    print("Critical Alert!")
else:
    print("System Healthy!")

print(" ")

# Challenge 4
cpu_usage = 75
memory_usage = 92
disk_usage = 98

print("Challenge 4: ")

if cpu_usage > 90 or memory_usage > 90 or disk_usage > 60:
    print("Critical Alert!")
else:
    print("System Healthy!")

print(" ")

# Challenge 5
cpu_usage = 91
memory_usage = 92
disk_usage = 98

print("Challenge 5: ")

if cpu_usage > 90 or memory_usage > 90 or disk_usage > 60:
    print("Critical Alert!")
else:
    print("System Healthy!")



# No certain condition causes the alert to trigger first because the alert is triggered if any of the conditions are true.
# Out:
# Task:
# Critical Alert!
#
# Challenge 1:
# Critical Alert!
#
# Challenge 2:
# Critical Alert!
#
# Challenge 3:
# Critical Alert!
#
# Challenge 4:
# Critical Alert!
#
# Challenge 5:
# Critical Alert!

# %% [markdown]
# # Bonus Challenge

# %%
# Task 
is_logged_in = True
is_in_stock = True
saved_payment = True
enough_wallet_balance = False
account_suspended = False

qualified = is_logged_in and is_in_stock and (saved_payment or enough_wallet_balance) and not account_suspended

print("Task: ")

if qualified:
    print("Order Confirmed!")
else:
    print("Order Failed!")

print(" ")


# Scenario 1 - Customer is not logged in.
# Reason: The customer has to be logged in to shop.

is_logged_in = False
is_in_stock = True
saved_payment = True
enough_wallet_balance = False
account_suspended = False

qualified = is_logged_in and is_in_stock and (saved_payment or enough_wallet_balance) and not account_suspended

print("Scenario 1: ")

if qualified:
    print("Order Confirmed!")
else:
    print("Order Failed!")

print(" ")


    
# Scenario 2 - Item is not in stock.
# Reason: An item has to be in stock to be bought.

is_logged_in = True
is_in_stock = False
saved_payment = True
enough_wallet_balance = False
account_suspended = False

qualified = is_logged_in and is_in_stock and (saved_payment or enough_wallet_balance) and not account_suspended

print("Scenario 2: ")
if qualified:
    print("Order Confirmed!")
else:
    print("Order Failed!")

print(" ")



# Scenario 3 - Account is suspended.
# Reason: An account has to be active to make purchases.

is_logged_in = True
is_in_stock = True
saved_payment = True
enough_wallet_balance = False
account_suspended = True

qualified = is_logged_in and is_in_stock and (saved_payment or enough_wallet_balance) and not account_suspended

print("Scenario 3:")

if qualified:
    print("Order Confirmed!")
else:
    print("Order Failed!")

print(" ")



# Scenario 4 - No saved payment but enough wallet balance.
# Reason: There is no saved payment but there is enough wallet balance.

is_logged_in = True
is_in_stock = True
saved_payment = False
enough_wallet_balance = True
account_suspended = False

print("Scenario 4: ")

qualified = is_logged_in and is_in_stock and (saved_payment or enough_wallet_balance) and not account_suspended

if qualified:
    print("Order Confirmed!")
else:
    print("Order Failed!")

print(" ")



# Scenario 5 - Saved payment but not enough wallet balance.
# Reason: There is saved payement but not enough wallet balance.

is_logged_in = True
is_in_stock = True
saved_payment = True
enough_wallet_balance = False
account_suspended = False

qualified = is_logged_in and is_in_stock and (saved_payment or enough_wallet_balance) and not account_suspended

print("Scenario 5:")

if qualified:
    print("Order Confirmed!")
else:
    print("Order Failed!")
# Out:
# Task:
# Order Confirmed!
#
# Scenario 1:
# Order Failed!
#
# Scenario 2:
# Order Failed!
#
# Scenario 3:
# Order Failed!
#
# Scenario 4:
# Order Confirmed!
#
# Scenario 5:
# Order Confirmed!
