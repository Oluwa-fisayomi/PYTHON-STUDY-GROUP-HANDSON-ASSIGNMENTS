# %% [markdown]
# ## Exercise 1 - Customer Registration

# %%
customer_name = "Owolabi Ayotomiwa"
email_address = "ayotomiwaowolabi@gmail.com"
phone_number = "+2348148491029"
country = "Nigeria"
occupation = "Data Analyst"

print("Customer Registration")
print("Name: ",customer_name)
print("Email: ",email_address)
print("Phone: ",phone_number)
print("Country: ",country)
print("Occupation: ",occupation)
# Out:
# Customer Registration
# Name:  Owolabi Ayotomiwa
# Email:  ayotomiwaowolabi@gmail.com
# Phone:  +2348148491029
# Country:  Nigeria
# Occupation:  Data Analyst

# %% [markdown]
# ## Exercise 2 - Hospital Patient Record

# %%
patient_name = "Sarah Johnson"
doctor_name = "David Musa"
diagnosis = "Malaria"
blood_group = "O+"
hospital_name = "Federal Medical Centre"

report = f"""PATIENT RECORD
Patient: {patient_name}
Doctor: {doctor_name}
Diagnosis: {diagnosis}
Blood Group: {blood_group}
Hospital: {hospital_name}
"""
print(report)
# Out:
# PATIENT RECORD
# Patient: Sarah Johnson
# Doctor: David Musa
# Diagnosis: Malaria
# Blood Group: O+
# Hospital: Federal Medical Centre

# %% [markdown]
# ## Exercise 3: AI Prompt Builder

# %%
prompt = """
You are an AI Assistant.
Analyze customer feedback.
Identify common complaints.
Provide recommendations.
Generate a summary report.
"""

print(prompt)
# Out:
# You are an AI Assistant.
# Analyze customer feedback.
# Identify common complaints.
# Provide recommendations.
# Generate a summary report.

# %%
# Bonus Challenge
prompt = """
You are an AI Assistant.
Analyze customer feedback.
Identify common complaints.
Provide recommendations.
Generate a summary report.
Generate isssues that require immediate attention.
"""

print(prompt)
# Out:
# You are an AI Assistant.
# Analyze customer feedback.
# Identify common complaints.
# Provide recommendations.
# Generate a summary report.
# Generate isssues that require immediate attention.

# %% [markdown]
# ## Real World Case Study

# %%
customer_name = "Sarah Johnson"
product_name = "Wireless Mouse"
product_category = "Computer Accessories"
customer_ratings = "5 Stars"
customer_review = """
The product arrived on time, was easy to 
install, and exceeded my expectations.
I would definitely recommend it to others.
"""

report = f"""
============================================
          CUSTOMER FEEDBACK REPORT
============================================

Customer Name: {customer_name}
Product: {product_name}
Category: {product_category}
Rating: {customer_ratings}

Customer Review
-------------------------
{customer_review}

============================================
Thank you for your feedback!
============================================
"""

print(report)
# Out:
# ...
#           CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name: Sarah Johnson
# Product: Wireless Mouse
# Category: Computer Accessories
# Rating: 5 Stars
#
# Customer Review
# -------------------------
#
# The product arrived on time, was easy to
# install, and exceeded my expectations.
# I would definitely recommend it to others.
#
#
# ...
# Thank you for your feedback!
# ...

# %% [markdown]
# ## Bonus Challenge

# %%
# I added the company's name and support email at the end of the report
# I displayed a welcome message before the report using a seperate multiline string

customer_name = "Sarah Johnson"
product_name = "Wireless Mouse"
product_category = "Computer Accessories"
customer_ratings = "5 Stars"
customer_review = """
The product arrived on time, was easy to 
install, and exceeded my expectations.
I would definitely recommend it to others.
"""



message = """
============================================
WELCOME TO OUR CUSTOMER
FEEDBACK MANAGEMENT SYSTEM!
============================================
"""

report = f"""
============================================
          CUSTOMER FEEDBACK REPORT
============================================

Customer Name: {customer_name}
Product: {product_name}
Category: {product_category}
Rating: {customer_ratings}

Customer Review
-------------------------
{customer_review}

============================================
Thank you for your feedback!
============================================

Company: Hermes Analytics and Co
Support Email: hermes121@gmail.com
"""




print(message)
print(report)
# Out:
# ...
# WELCOME TO OUR CUSTOMER
# FEEDBACK MANAGEMENT SYSTEM!
# ...
#
#
# ...
#           CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name: Sarah Johnson
# Product: Wireless Mouse
# Category: Computer Accessories
# Rating: 5 Stars
#
# Customer Review
# -------------------------
#
# The product arrived on time, was easy to
# install, and exceeded my expectations.
# I would definitely recommend it to others.
#
#
# ...
# Thank you for your feedback!
# ...
#
# Company: Hermes Analytics and Co
# Support Email: hermes121@gmail.com
