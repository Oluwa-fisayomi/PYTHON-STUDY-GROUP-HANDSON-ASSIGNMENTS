# %% [markdown]
# # Exercise 1: Creating Variables

# %%
user_name = "My name is Owolabi Ayotomiwa."
user_age = "My age is 17."
user_country = "My country is Nigeria."

print(user_name)
print(user_age)
print(user_country)
# Out:
# My name is Owolabi Ayotomiwa.
# My age is 17.
# My country is Nigeria.

# %% [markdown]
# # Exercise 2: Salary Calculation

# %%
basic_salary = 180000
bonus = 35000

total_salary = initial_salary + bonus

print("Basic Salary: ", basic_salary)
print("Bonus: ", bonus)
print("Total Salary: ", total_salary)
# Out:
# Basic Salary:  180000
# Bonus:  35000
# Total Salary:  215000

# %% [markdown]
# # Exercise 3: User Input

# %%
user_name = input("Enter your name: ")
favorite_language = input("Enter your favorite programming language: ")

print(" ")

print("Hello ", user_name)
print("Your favorite programming language is ", favorite_language)
# Out:
# Enter your name:  Owolabi Ayotomiwa
# Enter your favorite programming language:  JavaScript
#
# Hello  Owolabi Ayotomiwa
# Your favorite programming language is  JavaScript

# %% [markdown]
# # Exercise 4: Working wih Data Types

# %%
number = 10
amount = 12.5
user_name = "Owolabi Ayotomiwa"
boolean = False

print(type(number))
print(type(amount))
print(type(user_name))
print(type(boolean))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# # Exercise 5: Dynamic Typing

# %%
variable = 10

print("Before Change: ", type(variable))

variable = "Ayotomiwa"

print("After Change: ", type(variable))
# Out:
# Before Change:  <class 'int'>
# After Change:  <class 'str'>

# %% [markdown]
# # Mini Project: Student Information Card

# %%
print("Welcome!")
print("Kindly fill in your details.")

print(" ")

user_name = input("Name: ")
user_age = int(input("Age: "))
user_course = input("Course: ")
user_country = input("Country: ")

print(" ")

print("==============================")
print("   STUDENT INFORMATION CARD   ")
print("==============================")

print(" ")

print("Name:    ", user_name)
print("Age:     ", user_age)
print("Course:  ", user_course)
print("Country: ", user_country)

print(" ")

print("----------------")
print("   Data Types   ")
print("----------------")

type_name = type(user_name)
type_age = type(user_age)
type_course = type(user_course)
type_country = type(user_country)

print(" ")

print("Name:    ", type_name)
print("Age:     ", type_name)
print("Course:  ", type_name)
print("Country: ", type_country)
# Out:
# Welcome!
# Kindly fill in your details.
# Name:  OWOLABI AYOTOMIWA
# Age:  17
# Course:  COMPUTER SCIENCE
# Country:  NIGERIA
#
# ...
#    STUDENT INFORMATION CARD
# ...
#
# Name:     OWOLABI AYOTOMIWA
# Age:      17
# Course:   COMPUTER SCIENCE
# Country:  NIGERIA
#
# ----------------
#    Data Types
# ----------------
#
# Name:     <class 'str'>
# Age:      <class 'str'>
# Course:   <class 'str'>
# Country:  <class 'str'>

# %% [markdown]
# # Bonus Challenge

# %%
user_age = int(input("Enter your age: "))

print("Age: ", user_age)

type_age = type(user_age)

print("Data Type: ", T)
print(type_age)
# Out:
# Enter your age:  17
# Age:  17
# Data Type:
# <class 'int'>
