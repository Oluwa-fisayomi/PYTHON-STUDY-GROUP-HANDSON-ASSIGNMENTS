# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## Industry Scenario - Employee Record Information Extractor

# %%
employee_record = "EMP-HR-2026-004512"

print(f"""
Employee Prefix:          {employee_record[0:3]}
Department Code:          {employee_record[4:6]}
Employment Year:          {employee_record[7:11]}
Employee Number:          {employee_record[12:18]}
First 10 Characters:      {employee_record[0:10]}
Last 6 Characters:        {employee_record[12:18]}
Every Second Character:   {employee_record[::2]}
Every Third Character:    {employee_record[::3]}
Entire Record in Reverse: {employee_record[::-1]}
""")
# Out:
# Employee Prefix:          EMP
# Department Code:          HR
# Employment Year:          2026
# Employee Number:          004512
# First 10 Characters:      EMP-HR-202
# Last 6 Characters:        004512
# Every Second Character:   EPH-06041
# Every Third Character:    E--205
# Entire Record in Reverse: 215400-6202-RH-PME

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ## Industry Scenario - Banking Card Security Formatter

# %%
card_number = "5489123476549876"

print(f"""
First 4 digits:           {card_number[0:4]}
Last 4 digits:            {card_number[12:16]}
Middle 8 digits:          {card_number[4:12]}
Every second digit:       {card_number[::2]}
Every third digit:        {card_number[::3]}
Entire card in reverse:   {card_number[::-1]}
Last 8 digits in reverse: {card_number[-1:-9:-1]}
""")
# Out:
# First 4 digits:           5489
# Last 4 digits:            9876
# Middle 8 digits:          12347654
# Every second digit:       58137597
# Every third digit:        593696
# Entire card in reverse:   6789456743219845
# Last 8 digits in reverse: 67894567

# %% [markdown]
# ## Bonus Challenge

# %%
card_number = "5489123476549876"

print("Masked Card: ")
print("**** **** **** " + card_number[12:16] )
# Out:
# Masked Card:
# **** **** **** 9876

# %% [markdown]
# # Exercise 3

# %% [markdown]
# ## Industry Scenario - Customer Information Processor

# %%
# Step 1
customer_record = "CUS-LAG-2026-000451"

# Step 2
print(f"""
Customer Prefix:          {customer_record[0:3]}
City Code:                {customer_record[4:7]}
Registration Year:        {customer_record[8:12]}
Customer Number:          {customer_record[13:19]}
First 8 characters:       {customer_record[0:8]}
Last 5 characters:        {customer_record[-5:]}
Every second character:   {customer_record[::2]}
Every third character:    {customer_record[::3]}
Entire record in reverse: {customer_record[::-1]}
""")

# Step 3

customer_name = "Christopher Johnson"

print(f"""
First Name:                        {customer_name[0:11]}
Last Name:                         {customer_name[12:]}
First 5 letters of the first name: {customer_name[0:5]}
Last 7 letters of the last name:   {customer_name[12:]}
Entire name in reverse:            {customer_name[::-1]}
""")
# Out:
# Customer Prefix:          CUS
# City Code:                LAG
# Registration Year:        2026
# Customer Number:          000451
# First 8 characters:       CUS-LAG-
# Last 5 characters:        00451
# Every second character:   CSLG22-041
# Every third character:    C-G0-01
# Entire record in reverse: 154000-6202-GAL-SUC
#
#
# First Name:                        Christopher
# Last Name:                         Johnson
# First 5 letters of the first name: Chris
# Last 7 letters of the last name:   Johnson
# Entire name in reverse:            nosnhoJ rehpotsirhC
